# %% [markdown]
# ## Binary Search
#
# Search from sorted list of length $n$.
#
# * Time: $O(\log n)$
# * Space: $O(1)$

# %%
from typing import List

class BinarySearch:
    
    def __call__(self, arr: List[int], target: int) -> int:
        left, right = 0, len(arr) - 1
        while left <= right:
            mid = left + (right - left) // 2
            if arr[mid] == target:
                return mid
            elif arr[mid] < target:
                left = mid + 1
            else:
                right = mid - 1
        return -1

# %%
bs = BinarySearch()

bs([1, 2, 3, 4, 5], 3)
bs([i for i in range(0, 500, 5)], 80)
# Out:
# 16
